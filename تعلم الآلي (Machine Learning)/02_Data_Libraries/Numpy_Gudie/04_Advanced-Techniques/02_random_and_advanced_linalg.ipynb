# %%
import numpy as np

# %%
# تثبيت العشوائية لتوثيق التجارب وضمان خروج نفس النتائج دائماً عند التشغيل
np.random.seed(42)

# %% [markdown]
# # 1. توليد مصفوفات الأوزان عشوائياً

# %%
w_normal = np.random.randn(3, 3) # توزيع طبيعي قياسي (Mean=0, Std=1)
w_uniform = np.random.rand(3, 3) # توزيع منتظم بين 0 و 1

# %% [markdown]
# # 2. الجبر الخطي المتقدم

# %%
matrix = np.array([[4, 7], [2, 6]])
matrix_inverse = np.linalg.inv(matrix) # حساب مقلوب المصفوفة لفك المعادلات
eigenvalues, eigenvectors = np.linalg.eig(matrix) # القيم والناقلات الذاتية (مهمة لـ PCA)
