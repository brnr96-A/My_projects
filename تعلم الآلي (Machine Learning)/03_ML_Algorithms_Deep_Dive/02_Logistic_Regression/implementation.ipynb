# %%
pythonfrom sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# # 1. توليد بيانات تصنيف ثنائي

# %%
X_cls, y_cls = make_classification(n_samples=100, n_features=2, n_redundant=0, random_state=42)

# %% [markdown]
# # 2. تقسيم البيانات

# %%
X_train, X_test, y_train, y_test = train_test_split(X_cls, y_cls, test_size=0.2, random_state=42)

# %% [markdown]
# # 3. التدريب

# %%
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)

# %% [markdown]
# # 4. التنبؤ بالاحتمالات والفئات

# %%
y_pred = log_reg.predict(X_test)
y_probs = log_reg.predict_proba(X_test)[:, 1] # احتمالية الفئة 1

# %% [markdown]
# # 5. النتائج

# %%
print("\n--- Logistic Regression Results ---")
print(f"Test Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print("Classification Report:\n", classification_report(y_test, y_pred))
