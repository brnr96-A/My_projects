# %%
from sklearn.linear_model import ElasticNet

# %%
# استخدام نفس البيانات السابقة للتدريب
elastic_model = ElasticNet(alpha=0.1, l1_ratio=0.5) # مزيج متساوٍ 50% لكل نوع عقوبة
elastic_model.fit(X_train, y_train)

# %%
print("\n--- ElasticNet Regression Results ---")
print(f"ElasticNet Weights: {elastic_model.coef_}")
print(f"Test Score (R2): {elastic_model.score(X_test, y_test):.4f}")
