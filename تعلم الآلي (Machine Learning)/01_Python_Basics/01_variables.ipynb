# %% [markdown]
# المتغيرات والأنواع في بايثون

# %%
# المتغيرات تخزن البيانات 
candidate = "Omar"      # نص (String)
experience = 5          # عدد صحيح (Integer)
accuracy = 0.94         # عدد عشري (Float)
is_ready = True         # قيمة منطقية (Boolean)

# %% [markdown]
# طباعة المتغيرات و اﻷنواع

# %%
# طباعة الأنواع للتأكد من حجز الذاكرة
print(f"الاسم: {candidate} -> النوع: {type(candidate)}")
print(f"الدقة: {accuracy} -> النوع: {type(accuracy)}")
print(f"الخبرة: {experience} سنوات -> النوع: {type(experience)}")
